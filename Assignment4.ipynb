# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from dateutil.parser import *


data_2009 = pd.read_csv('cpcb_dly_aq_uttar_pradesh-2009.csv')
data_2009.columns= ['Date', 'State', 'City','Location', 'Type', 'SO2','NO2', 'PM10', 'PM25']
data_2009['Date'] = data_2009.Date.apply(parse,dayfirst =True)

f = lambda x: x.strftime('%m')
data_2009['Month'] = data_2009.Date.apply(f)
data_2009 = data_2009[['Date', 'Month', 'State','City', 'SO2', 'NO2', 'PM10', 'PM25']]
group_2009 = data_2009[['SO2', 'NO2', 'PM10']].groupby(by=[data_2009.City]).mean()
group_2009['Year'] = 2009
group_2009['City'] = group_2009.index.get_level_values(0)
# group_2009['Month'] = group_2009.index.get_level_values(1)

# %%
data_2010 = pd.read_csv('cpcb_dly_aq_uttar_pradesh-2010.csv')
data_2010.columns = ['Station', 'Date', 'State', 'City', 'Location', 'Agency', 'Type', 'SO2','NO2', 'PM10', 'PM25']
data_2010['Date'] = data_2010.Date.apply(parse, dayfirst =True)

data_2010['Month'] = data_2010.Date.apply(f)

data_2010 = data_2010[['Station', 'Date', 'Month', 'State','City', 'SO2', 'NO2', 'PM10']]
group_2010 = data_2010[['SO2','NO2', 'PM10']].groupby(by=[data_2010.City]).mean()
group_2010['Year'] = 2010
group_2010['City'] = group_2010.index.get_level_values(0)
# group_2010['Month'] = group_2010.index.get_level_values(1)

# %%
data_2011 = pd.read_csv('cpcb_dly_aq_uttar_pradesh-2011.csv')
data_2011.columns = ['Station', 'Date', 'State', 'City', 'Location', 'Agency', 'Type', 'SO2','NO2', 'PM10', 'PM25']
data_2011['Date'] = data_2011.Date.apply(parse, dayfirst =True)

f = lambda x: x.strftime('%m')
data_2011['Month'] = data_2011.Date.apply(f)

data_2011 = data_2011[['Station', 'Date', 'Month', 'State','City', 'SO2', 'NO2', 'PM10']]
group_2011 = data_2011[['SO2','NO2', 'PM10']].groupby(by=[data_2011.City]).mean()
group_2011['Year'] = 2011
group_2011['City'] = group_2011.index.get_level_values(0)
# group_2011['Month'] = group_2011.index.get_level_values(1)

# %%
data_2012 = pd.read_csv('cpcb_dly_aq_uttar_pradesh-2012.csv')
data_2012.columns = ['Station', 'Date', 'State', 'City', 'Location', 'Agency', 'Type', 'SO2','NO2', 'PM10', 'PM25']
data_2012['Date'] = data_2012.Date.apply(parse, dayfirst =True)

f = lambda x: x.strftime('%m')
data_2012['Month'] = data_2012.Date.apply(f)

data_2012 = data_2012[['Station', 'Date', 'Month', 'State','City', 'SO2', 'NO2', 'PM10']]
group_2012 = data_2012[['SO2','NO2', 'PM10']].groupby(by=[data_2012.City]).mean()
group_2012['Year'] = 2012
group_2012['City'] = group_2012.index.get_level_values(0)
# group_2012['Month'] = group_2012.index.get_level_values(1)

# %%
data_2013 = pd.read_csv('cpcb_dly_aq_uttar_pradesh-2013.csv')
data_2013.columns = ['Station', 'Date', 'State', 'City', 'Location', 'Agency', 'Type', 'SO2','NO2', 'PM10', 'PM25']
data_2013['Date'] = data_2013.Date.apply(parse, dayfirst =True)

f = lambda x: x.strftime('%m')
data_2013['Month'] = data_2013.Date.apply(f)

data_2013 = data_2013[['Station', 'Date', 'Month', 'State','City', 'SO2', 'NO2', 'PM10']]
group_2013 = data_2013[['SO2','NO2', 'PM10']].groupby(by=[data_2013.City]).mean()
group_2013['Year'] = 2013
group_2013['City'] = group_2013.index.get_level_values(0)
# group_2013['Month'] = group_2013.index.get_level_values(1)

# %%
group_combined = pd.concat([group_2009,group_2010,group_2011,group_2012,group_2013]).reset_index(drop=True)
# group_combined['City'] = group_combined.index
# group_combined.reset_index(drop=True)
group_combined = group_combined.sort_values(['City','Year'])
monthly_combined = group_combined.groupby(['City','Year']).mean()

monthly_combined['City'] = monthly_combined.index.get_level_values(0)
monthly_combined['Year'] = monthly_combined.index.get_level_values(1)

# import calendar
# g = lambda x: calendar.month_name[int(x)]

# monthly_combined['Month_name'] = monthly_combined.Month.apply(g)

# %%
plt.style.use('seaborn-colorblind')
# %matplotlib notebook
import seaborn as sns

sns.set(style="white", context="talk")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 10), sharex=True)
plt.subplots_adjust(bottom=0.25)

# items = ['03', '06', '09', '12']
bar1 = sns.barplot(data = monthly_combined, 
                   x='City', y = 'NO2', hue='Year', ax=ax1, palette='pastel')  
bar1.axhline(y = 40, color = 'grey', alpha = 0.5)
bar2 = sns.barplot(data = monthly_combined, 
                   x='City', y = 'SO2', hue='Year', ax=ax2,palette='pastel')
bar2.axhline(y = 20, color = 'grey', alpha = 0.5)
bar3 = sns.barplot(data = monthly_combined, 
                   x='City', y = 'PM10', hue='Year', ax=ax3, palette='pastel')
bar3.axhline(y = 20, color = 'grey', alpha = 0.5)

_ = bar3.set_xticklabels(bar3.get_xticklabels(),rotation=90)

bar1.legend('')
bar1.set_xlabel('')
bar2.legend('')
bar2.set_xlabel('')
_ = bar3.legend(loc='best',fontsize='xx-small')
_2 = bar1.set_title('5-year annual pollution trend for cities in Uttar Pradesh, India \
                    \nAll units are in micrograms per cubic meter')  
# _ = group_combined[['SO2', 'NO2', 'PM10']].plot(kind='bar', figsize=(8,8), subplots=True, color=plot_colors)
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
canvas = FigureCanvasAgg(plt.gcf())
canvas.print_png('Assignment4.png')
